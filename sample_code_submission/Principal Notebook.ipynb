# %% [markdown]
# ***
# # Starting Kit - Black Swan HiggsML Course
# ***

# %% [markdown]
# ## Setup
# `COLAB` determines whether this notebook is running on Google Colab.

# %%
COLAB = 'google.colab' in str(get_ipython())

# %%
if COLAB:
    ! git clone https://github.com/blackSwanCS/Collaboration_D 
    # %cd Collaboration_D

# HiggsML utility package should not be modified
# %pip install HiggsML
# Out:
# Requirement already satisfied: HiggsML in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (0.0.11)
# Requirement already satisfied: matplotlib in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from HiggsML) (3.8.4)
# Requirement already satisfied: numpy in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from HiggsML) (1.26.4)
# Requirement already satisfied: pandas in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from HiggsML) (2.2.1)
# Requirement already satisfied: pyarrow in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from HiggsML) (14.0.2)
# Requirement already satisfied: requests in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from HiggsML) (2.32.3)
# Requirement already satisfied: scikit-learn in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from HiggsML) (1.5.0)
# Requirement already satisfied: seaborn in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from HiggsML) (0.13.2)
# Requirement already satisfied: setuptools in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from HiggsML) (69.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from matplotlib->HiggsML) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from matplotlib->HiggsML) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from matplotlib->HiggsML) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from matplotlib->HiggsML) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from matplotlib->HiggsML) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from matplotlib->HiggsML) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from matplotlib->HiggsML) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from matplotlib->HiggsML) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from pandas->HiggsML) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from pandas->HiggsML) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from requests->HiggsML) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from requests->HiggsML) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from requests->HiggsML) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from requests->HiggsML) (2024.6.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from scikit-learn->HiggsML) (1.13.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from scikit-learn->HiggsML) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from scikit-learn->HiggsML) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\alexis\anaconda3\envs\eibs\lib\site-packages (from python-dateutil>=2.7->matplotlib->HiggsML) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Test Settings
# The Test setting sets the test conditions in ingestion.
# This includes what systematics you want and how many psuedo experiments you want.

# %%
TEST_SETTINGS = {
"systematics": {  # Systematics to use
    "tes": False, # tau energy scale
    "jes": False, # jet energy scale
    "soft_met": False, # soft term in MET
    "w_scale": False, # W boson scale factor
    "bkg_scale": False, # Background scale factor
    },
"num_pseudo_experiments" : 10 , # Number of pseudo-experiments to run per set
"num_of_sets" : 2, # Number of sets of pseudo-experiments to run
} 

USE_RANDOM_MUS = True

# %% [markdown]
# ### Imports

# %%
from sys import path
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
from itertools import product
from numpy.random import RandomState
import warnings
import os
import sys
from seaborn import heatmap
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Directories

# %%
root_dir = os.getcwd()
print("Root directory is", root_dir)

input_dir = os.path.join(root_dir, "sample_data")
output_dir = os.path.join(root_dir, "sample_result_submission")
submission_dir = os.path.join(root_dir, "sample_code_submission")

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
test_settings = TEST_SETTINGS.copy()

if USE_RANDOM_MUS:
    test_settings[ "ground_truth_mus"] = (np.random.uniform(0.1, 3, test_settings["num_of_sets"])).tolist()
    
    random_settings_file = os.path.join(output_dir, "random_mu.json")
    with open(random_settings_file, "w") as f:
        json.dump(test_settings, f)
else:
    test_settings_file = os.path.join(input_dir, "test", "settings", "data.json")
    with open(test_settings_file) as f:
        test_settings = json.load(f)
# Out:
# Root directory is c:\Users\Alexis\OneDrive\Bureau\Cours\Semestre 2\Black Swan\EI\Collaboration_D\sample_code_submission

# %% [markdown]
# ### Add directories to path

# %%
path.append(submission_dir)

# %%
import HiggsML.visualization as visualization

# %% [markdown]
# ## Import Submission Model
# We import a class named `Model` from the submission file (`model.py`). This `Model` class has the following methods:
# - `init`: receives train set and systematics class as input
# - `fit`: can be used for training
# - `predict`: receives one test set and outputs a dictionary with the following keys
#     - `mu_hat` : predicted mu $\hat{\mu}$
#     - `delta_mu_hat`: $\Delta{\hat{\mu}}$ bound for $\mu$
#     - `p16`: 16th percentile
#     - `p84`: 84th percentile
#
# In this example code, the `Model` class implements a basic model with 2 different model trained to predict the class label.
#
# * 1 XGBoost BDT ( [see](/home/chakkappai/Work/ST4_CS/Collaboration_A/sample_code_submission/boosted_decision_tree.py) )
# * 2 Tebsorflow NN  ( [see](/home/chakkappai/Work/ST4_CS/Collaboration_A/sample_code_submission/neural_network.py) )
#
# The feature engineering is in where you can include derived quantities and decide which feature should be needed. ( [see](/home/chakkappai/Work/ST4_CS/Collaboration_A/sample_code_submission/feature_engineering.py) )
#
# the statistical analysis part is where yoiu write the mu finding calculation using the output of the classifier. ( [see](/home/chakkappai/Work/ST4_CS/Collaboration_A/sample_code_submission/statistical_analysis.py) )
#
# If running in Collab, click the folder icon in the left sidebar to open the file browser.

# %%
from model import Model

# %% [markdown]
# ## Data
#
# ### ⚠️ Note:
# The data used here is a small sample data is for demonstration only to get a view of what the data looks like.

# %% [markdown]
# `USE_PUBLIC_DATASET` determines whether to use a public dataset provided for the participants or use a small sample datafor quick execution of this notebook

# %%
USE_PUBLIC_DATASET = True

# %% [markdown]
# `USE_PUBLIC_DATASET` determines whether to use a public dataset provided for the participants or use a small subset of the data for quick execution of this notebook

# %%
if USE_PUBLIC_DATASET:
    from HiggsML.datasets import BlackSwan_public_dataset as public_dataset
    data = public_dataset()
else:
    data = Data(input_dir)

# %% [markdown]
# The function loads the downloaded data in the public_data folder or downloads the data from codabench using `wget` in the absence of the downloaded data,

# %%
# load train set
data.load_train_set()
# Out:
# [*] Loading Train data
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5090511 entries, 0 to 5090510
# Columns: 16 entries, PRI_lep_pt to PRI_met_phi
# dtypes: float32(16)
# memory usage: 310.7 MB
# None
# [*] Train data loaded successfully

# %%
# load test sets
data.load_test_set()
# Out:
# [*] Loading Test data
# [*] Test data loaded successfully

# %% [markdown]
# ***
# # Visualize
# ***
# - Visualize Train set

# %%
train_visualize = visualization.Dataset_visualise(
    data_set=data.get_train_set(),
    columns=[
        "PRI_jet_leading_pt",
        "PRI_met",
        "PRI_lep_phi",
        "PRI_had_eta",
    ],
    name="Train Set",
)

# %%
# Show data summary
train_visualize.examine_dataset()
# Out:
# [*] --- Dataset name : Train Set
# [*] --- Number of events : 5090511
# [*] --- Number of features : 16
#    diboson   40590.00000000001
#    htautau   3639.000000000001
#    ttbar   158761.0
#    ztautau   3544018.9999999986
# [*] --- Number of signal events : 4233398
# [*] --- Number of background events : 857113
# [*] --- Examples of all features
#    PRI_lep_pt  PRI_lep_eta  PRI_lep_phi  PRI_had_pt  PRI_had_eta  PRI_had_phi  \
# 0   33.716999       -0.009       -1.614   42.567001        0.391        1.512
# 1   39.069000       -0.382        2.876   45.743000        0.369       -0.165
# 2   26.211000        0.736       -2.294   43.819000        0.565        0.889
# 3   55.631001       -0.277        1.425   46.077999        0.190       -1.295
# 4   96.626999        0.548        2.112   64.114998       -2.041       -2.114
#
#    PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# 0           42.567001                0.391                1.512
# 1           45.743000                0.369               -0.165
# 2           43.819000                0.565                0.889
# 3           49.319000                1.085                3.036
# 4           64.114998               -2.041               -2.114
#
#    PRI_jet_subleading_pt  PRI_jet_subleading_eta  PRI_jet_subleading_phi  \
# 0              -7.000000                  -7.000                  -7.000
# 1              -7.000000                  -7.000                  -7.000
# 2              -7.000000                  -7.000                  -7.000
# 3              46.077999                   0.190                  -1.295
# 4              24.503000                  -0.549                  -0.182
#
#    PRI_n_jets  PRI_jet_all_pt    PRI_met  PRI_met_phi
# 0        -7.0       42.567001  18.089001       -2.276
# 1        -7.0       45.743000  11.859000        0.983
# 2        -7.0       43.819000   8.625000       -0.087
# 3        -1.0       95.397003  33.098999       -0.798
# 4         1.0       88.617996  36.653000        0.112
# [*] --- Description of all features
#          PRI_lep_pt   PRI_lep_eta   PRI_lep_phi    PRI_had_pt   PRI_had_eta  \
# count  5.090511e+06  5.090511e+06  5.090511e+06  5.090511e+06  5.090511e+06
# mean   4.003698e+01  3.925515e-04  1.407315e-03  5.060483e+01 -2.050461e-04
# std    2.381429e+01  1.170707e+00  1.810495e+00  2.750230e+01  1.201028e+00
# min    2.000000e+01 -2.500000e+00 -3.142000e+00  2.285000e+01 -2.688000e+00
# 25%    2.583500e+01 -8.910000e-01 -1.569000e+00  3.388800e+01 -9.250000e-01
# 50%    3.331800e+01  0.000000e+00  2.000000e-03  4.432600e+01 -1.000000e-03
# 75%    4.544000e+01  8.930000e-01  1.573000e+00  5.823900e+01  9.250000e-01
# max    1.261630e+03  2.500000e+00  3.142000e+00  1.260630e+03  2.728000e+00
#
#         PRI_had_phi  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# count  5.090511e+06        5.090511e+06         5.090511e+06
# mean   4.544730e-05        7.441782e+01        -4.562408e-04
# std    1.809866e+00        5.820190e+01         1.544254e+00
# min   -3.142000e+00        2.287800e+01        -4.962000e+00
# 25%   -1.570000e+00        4.107000e+01        -1.115000e+00
# 50%    0.000000e+00        5.537100e+01        -2.000000e-03
# 75%    1.570000e+00        8.354200e+01         1.114000e+00
# max    3.142000e+00        1.509400e+03         4.962000e+00
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# count         5.090511e+06           5.090511e+06            5.090511e+06
# mean         -4.969829e-04           3.285685e+01           -2.396049e+00
# std           1.809246e+00           3.997153e+01            3.621691e+00
# min          -3.142000e+00          -7.000000e+00           -7.000000e+00
# 25%          -1.572000e+00          -7.000000e+00           -7.000000e+00
# 50%          -1.000000e-03           3.107700e+01           -1.369000e+00
# 75%           1.570000e+00           5.053000e+01            5.960000e-01
# max           3.142000e+00           1.276360e+03            4.998000e+00
#
#        PRI_jet_subleading_phi    PRI_n_jets  PRI_jet_all_pt       PRI_met  \
# count            5.090511e+06  5.090511e+06    5.090511e+06  5.090511e+06
# mean            -2.394187e+00 -2.390822e+00    1.354049e+02  3.529635e+01
# std              3.603255e+00  3.377576e+00    1.256692e+02  3.601789e+01
# min             -7.000000e+00 -9.000000e+00    2.287800e+01  4.000000e-03
# 25%             -7.000000e+00 -7.000000e+00    5.102600e+01  1.367400e+01
# 50%             -1.631000e+00 -1.000000e+00    9.083600e+01  2.441600e+01
# 75%              7.760000e-01  0.000000e+00    1.761230e+02  4.313200e+01
# max              3.142000e+00  1.000000e+01    3.542470e+03  1.242130e+03
#
#         PRI_met_phi
# count  5.090511e+06
# mean   4.293358e-04
# std    1.809704e+00
# min   -3.142000e+00
# 25%   -1.570000e+00
# 50%    0.000000e+00
# 75%    1.571000e+00
# max    3.142000e+00

# %%
# Show data summary
train_visualize.histogram_dataset()

# %%
train_visualize.stacked_histogram("PRI_had_eta")
# Out:
# diboson (147729,)
# diboson (147729,)
# htautau (30,)
# ttbar (189157,)
# ttbar (189157,)
# ztautau (520227,)
# ztautau (520227,)

# %%
# Show data summary
train_visualize.pair_plots(sample_size=100)

# %%
syst_train_data = data.get_syst_train_set()

# %%
# Pair plots of train set with systematics
train_visualize.pair_plots_syst(syst_train_data["data"], sample_size=100)

# %%
bootstraped_data = data.generate_psuedo_exp_data()

# %%
# Show data summary
train_visualize.examine_dataset()
# Out:
# [*] --- Dataset name : Train Set
# [*] --- Number of events : 5090511
# [*] --- Number of features : 16
#    diboson   40590.00000000001
#    htautau   3639.000000000001
#    ttbar   158761.0
#    ztautau   3544018.9999999986
# [*] --- Number of signal events : 4233398
# [*] --- Number of background events : 857113
# [*] --- Examples of all features
#    PRI_lep_pt  PRI_lep_eta  PRI_lep_phi  PRI_had_pt  PRI_had_eta  PRI_had_phi  \
# 0   33.716999       -0.009       -1.614   42.567001        0.391        1.512
# 1   39.069000       -0.382        2.876   45.743000        0.369       -0.165
# 2   26.211000        0.736       -2.294   43.819000        0.565        0.889
# 3   55.631001       -0.277        1.425   46.077999        0.190       -1.295
# 4   96.626999        0.548        2.112   64.114998       -2.041       -2.114
#
#    PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# 0           42.567001                0.391                1.512
# 1           45.743000                0.369               -0.165
# 2           43.819000                0.565                0.889
# 3           49.319000                1.085                3.036
# 4           64.114998               -2.041               -2.114
#
#    PRI_jet_subleading_pt  PRI_jet_subleading_eta  PRI_jet_subleading_phi  \
# 0              -7.000000                  -7.000                  -7.000
# 1              -7.000000                  -7.000                  -7.000
# 2              -7.000000                  -7.000                  -7.000
# 3              46.077999                   0.190                  -1.295
# 4              24.503000                  -0.549                  -0.182
#
#    PRI_n_jets  PRI_jet_all_pt    PRI_met  PRI_met_phi
# 0        -7.0       42.567001  18.089001       -2.276
# 1        -7.0       45.743000  11.859000        0.983
# 2        -7.0       43.819000   8.625000       -0.087
# 3        -1.0       95.397003  33.098999       -0.798
# 4         1.0       88.617996  36.653000        0.112
# [*] --- Description of all features
#          PRI_lep_pt   PRI_lep_eta   PRI_lep_phi    PRI_had_pt   PRI_had_eta  \
# count  5.090511e+06  5.090511e+06  5.090511e+06  5.090511e+06  5.090511e+06
# mean   4.003698e+01  3.925515e-04  1.407315e-03  5.060483e+01 -2.050461e-04
# std    2.381429e+01  1.170707e+00  1.810495e+00  2.750230e+01  1.201028e+00
# min    2.000000e+01 -2.500000e+00 -3.142000e+00  2.285000e+01 -2.688000e+00
# 25%    2.583500e+01 -8.910000e-01 -1.569000e+00  3.388800e+01 -9.250000e-01
# 50%    3.331800e+01  0.000000e+00  2.000000e-03  4.432600e+01 -1.000000e-03
# 75%    4.544000e+01  8.930000e-01  1.573000e+00  5.823900e+01  9.250000e-01
# max    1.261630e+03  2.500000e+00  3.142000e+00  1.260630e+03  2.728000e+00
#
#         PRI_had_phi  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# count  5.090511e+06        5.090511e+06         5.090511e+06
# mean   4.544730e-05        7.441782e+01        -4.562408e-04
# std    1.809866e+00        5.820190e+01         1.544254e+00
# min   -3.142000e+00        2.287800e+01        -4.962000e+00
# 25%   -1.570000e+00        4.107000e+01        -1.115000e+00
# 50%    0.000000e+00        5.537100e+01        -2.000000e-03
# 75%    1.570000e+00        8.354200e+01         1.114000e+00
# max    3.142000e+00        1.509400e+03         4.962000e+00
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# count         5.090511e+06           5.090511e+06            5.090511e+06
# mean         -4.969829e-04           3.285685e+01           -2.396049e+00
# std           1.809246e+00           3.997153e+01            3.621691e+00
# min          -3.142000e+00          -7.000000e+00           -7.000000e+00
# 25%          -1.572000e+00          -7.000000e+00           -7.000000e+00
# 50%          -1.000000e-03           3.107700e+01           -1.369000e+00
# 75%           1.570000e+00           5.053000e+01            5.960000e-01
# max           3.142000e+00           1.276360e+03            4.998000e+00
#
#        PRI_jet_subleading_phi    PRI_n_jets  PRI_jet_all_pt       PRI_met  \
# count            5.090511e+06  5.090511e+06    5.090511e+06  5.090511e+06
# mean            -2.394187e+00 -2.390822e+00    1.354049e+02  3.529635e+01
# std              3.603255e+00  3.377576e+00    1.256692e+02  3.601789e+01
# min             -7.000000e+00 -9.000000e+00    2.287800e+01  4.000000e-03
# 25%             -7.000000e+00 -7.000000e+00    5.102600e+01  1.367400e+01
# 50%             -1.631000e+00 -1.000000e+00    9.083600e+01  2.441600e+01
# 75%              7.760000e-01  0.000000e+00    1.761230e+02  4.313200e+01
# max              3.142000e+00  1.000000e+01    3.542470e+03  1.242130e+03
#
#         PRI_met_phi
# count  5.090511e+06
# mean   4.293358e-04
# std    1.809704e+00
# min   -3.142000e+00
# 25%   -1.570000e+00
# 50%    0.000000e+00
# 75%    1.571000e+00
# max    3.142000e+00

# %% [markdown]
# ### Ingestion

# %%
from HiggsML.ingestion import Ingestion

ingestion = Ingestion(data)

# %%
# initialize submission
ingestion.init_submission(Model)
# Out:
# [*] Initializing Submmited Model
# [*] Loading Train data
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5090511 entries, 0 to 5090510
# Columns: 16 entries, PRI_lep_pt to PRI_met_phi
# dtypes: float32(16)
# memory usage: 310.7 MB
# None
# [*] Train data loaded successfully
# Full data:  (5090511, 16)
# Full Labels:  (5090511,)
# Full Weights:  (5090511,)
# sum_signal_weights:  3639.000000000001
# sum_bkg_weights:  3743369.999999998
#
#
# Training Data:  (3770937, 16)
# Training Labels:  (3770937,)
# Training Weights:  (3770937,)
# sum_signal_weights:  3639.0000000000005
# sum_bkg_weights:  3743369.9999999935
#
# Valid Data:  (1527153, 16)
# Valid Labels:  (1527153,)
# Valid Weights:  (1527153,)
# sum_signal_weights:  3639.0000000000036
# sum_bkg_weights:  3743369.9999999977
#
#
# feature engineering took 2.55 s, results:
#
#          PRI_lep_pt   PRI_lep_eta   PRI_lep_phi    PRI_had_pt   PRI_had_eta  \
# count  3.770937e+06  3.770937e+06  3.770937e+06  3.770937e+06  3.770937e+06
# mean   4.003678e+01  1.822653e-04  1.700528e-03  5.060574e+01 -3.370857e-04
# std    2.387261e+01  1.171679e+00  1.810829e+00  2.755300e+01  1.201598e+00
# min    2.000000e+01 -2.500000e+00 -3.142000e+00  2.287600e+01 -2.688000e+00
# 25%    2.583300e+01 -8.920000e-01 -1.569000e+00  3.388700e+01 -9.250000e-01
# 50%    3.331600e+01  0.000000e+00  2.000000e-03  4.432100e+01 -1.000000e-03
# 75%    4.544400e+01  8.920000e-01  1.573000e+00  5.822100e+01  9.240000e-01
# max    1.190700e+03  2.500000e+00  3.142000e+00  1.260630e+03  2.728000e+00
#
#         PRI_had_phi  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# count  3.770937e+06        3.770937e+06         3.770937e+06
# mean  -6.044020e-05        7.442527e+01        -6.816989e-04
# std    1.810693e+00        5.825805e+01         1.546558e+00
# min   -3.142000e+00        2.287800e+01        -4.962000e+00
# 25%   -1.570000e+00        4.107400e+01        -1.116000e+00
# 50%    0.000000e+00        5.536500e+01        -2.000000e-03
# 75%    1.569000e+00        8.354800e+01         1.115000e+00
# max    3.142000e+00        1.509400e+03         4.962000e+00
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# count         3.770937e+06           3.770937e+06            3.770937e+06
# mean         -6.586051e-04           3.286995e+01           -2.394652e+00
# std           1.810408e+00           4.010853e+01            3.634286e+00
# min          -3.142000e+00          -7.000000e+00           -7.000000e+00
# 25%          -1.573000e+00          -7.000000e+00           -7.000000e+00
# 50%          -1.000000e-03           3.108100e+01           -1.367000e+00
# 75%           1.571000e+00           5.053200e+01            5.970000e-01
# max           3.142000e+00           1.276360e+03            4.998000e+00
#
#        PRI_jet_subleading_phi    PRI_n_jets  PRI_jet_all_pt       PRI_met  \
# count            3.770937e+06  3.770937e+06    3.770937e+06  3.770937e+06
# mean            -2.393154e+00  1.658039e+00    1.354200e+02  3.530512e+01
# std              3.616163e+00  4.786827e-01    1.259238e+02  3.606967e+01
# min             -7.000000e+00  1.000000e+00    2.287800e+01  4.000000e-03
# 25%             -7.000000e+00  1.000000e+00    5.103500e+01  1.367200e+01
# 50%             -1.630000e+00  2.000000e+00    9.085300e+01  2.442200e+01
# 75%              7.770000e-01  2.000000e+00    1.761110e+02  4.315000e+01
# max              3.142000e+00  2.000000e+00    3.542470e+03  1.242130e+03
#
#         PRI_met_phi  DER_mass_vis      DER_pt_h  DER_mass_transverse_met_lep  \
# count  3.770937e+06  3.770937e+06  3.770937e+06                 3.770937e+06
# mean   4.792318e-04  8.359212e+01  6.266243e+01                 2.637269e+01
# std    1.809979e+00  3.211189e+01  6.940074e+01                 3.010241e+01
# min   -3.142000e+00  8.518233e+00  8.184660e-03                -7.000000e+00
# 25%   -1.569000e+00  6.700043e+01  1.707232e+01                 6.674157e+00
# 50%    0.000000e+00  7.974062e+01  3.700884e+01                 1.687271e+01
# 75%    1.571000e+00  9.426755e+01  8.270907e+01                 3.666925e+01
# max    3.142000e+00  2.411021e+03  1.515270e+03                 1.850061e+03
#
#        DER_mass_jet_jet  DER_deltaeta_jet_jet    DER_sum_pt  \
# count      3.770937e+06          3.770937e+06  3.770937e+06
# mean       1.619623e+02         -1.129757e+00  2.003315e+02
# std        2.771286e+02          4.396492e+00  1.193321e+02
# min       -7.000000e+00         -7.000000e+00  6.607200e+01
# 25%       -7.000000e+00         -7.000000e+00  1.265770e+02
# 50%        9.285464e+01          7.639999e-01  1.658330e+02
# 75%        2.045210e+02          2.122000e+00  2.323520e+02
# max        9.022885e+03          9.532000e+00  4.034321e+03
#
#        DER_met_phi_centrality  DER_prodeta_jet_jet  DER_deltar_tau_lep  \
# count            3.770937e+06         3.770937e+06        3.770937e+06
# mean             4.096358e-01        -2.181341e+00        2.943782e+00
# std              1.140391e+00         4.237648e+00        9.469593e-01
# min             -7.000000e+00        -2.270288e+01        3.538037e-01
# 25%             -9.963400e-01        -7.000000e+00        2.386124e+00
# 50%              1.058635e+00        -9.676940e-01        3.084621e+00
# 75%              1.371356e+00         7.021140e-01        3.473093e+00
# max              1.414214e+00         2.140206e+01        7.615928e+00
#
#        DER_lep_eta_centrality  DER_pt_ratio_lep_tau    DER_pt_tot
# count            3.770937e+06          3.770937e+06  3.770937e+06
# mean            -2.134607e+00          9.298275e-01  3.688540e+02
# std              3.515512e+00          6.592038e-01  4.268618e+02
# min             -7.000000e+00          1.588174e-02  3.952063e+01
# 25%             -7.000000e+00          5.399459e-01  1.229536e+02
# 50%              4.238238e-03          7.683811e-01  2.158233e+02
# 75%              5.293922e-01          1.106355e+00  4.198174e+02
# max              1.000000e+00          2.812246e+01  6.572239e+03
#
# Training Data:  (3770937, 28)
# Model is BDT

# %%
# fit submission
ingestion.fit_submission()
# Out:
# [*] Calling fit method of submitted model
# fitting XGBoost model
# XGBoost model fitted in 51.58941173553467 s
# L'estimateur de mu chapeau vaut : 0.9995048861436739
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 # fit submission
# ----> 2 ingestion.fit_submission()
#
# File c:\Users\Alexis\anaconda3\envs\EIBS\Lib\site-packages\HiggsML\ingestion.py:70, in Ingestion.fit_submission(self)
#      68 def fit_submission(self):
#      69     print("[*] Calling fit method of submitted model")
# ---> 70     self.model.fit()
#
# File c:\Users\Alexis\OneDrive\Bureau\Cours\Semestre 2\Black Swan\EI\Collaboration_D\sample_code_submission\model.py:171, in Model.fit(self)
#     168 self.saved_info = calculate_saved_info(self.model, self.training_set)
#     170 train_score = self.model.predict(self.training_set["data"])
# --> 171 train_results = compute_mu(train_score, self.training_set["weights"], self.saved_info)
#     173 self.valid_set["data"] = feature_engineering(self.valid_set["data"])
#     175 # ----------------------- STATS ---------------------------
#     176
#     177 # We define a list of values for jes
#
# File c:\Users\Alexis\OneDrive\Bureau\Cours\Semestre 2\Black Swan\EI\Collaboration_D\sample_code_submission\statistical_analysis.py:123, in compute_mu(score, weight, saved_info)
#     119 # print(nS, nB)
#     121 liste_n = n_bins(score, train_set["weights"], 0.5, (nS, nB, pS, pB, wS, wB))
# --> 123 mu_hat, del_mu_stat = incertitude(liste_n, nS, nB, pS, pB, wS, wB)
#     125 return {
#     126     "mu_hat": mu_hat,
#     127     "del_mu_stat": del_mu_stat,
#     128     # "del_mu_sys": del_mu_sys,
#     129     # "del_mu_tot": del_mu_tot,
#     130 }
#
# File c:\Users\Alexis\OneDrive\Bureau\Cours\Semestre 2\Black Swan\EI\Collaboration_D\sample_code_submission\statistical_analysis.py:85, in compute_mu.<locals>.incertitude(liste_n, liste_nS, liste_nB, pS, pB, wS, wB)
#      81 print(f"L'estimateur de mu chapeau vaut : {mini}")
#      83 mu_axis_values = np.linspace(mini-1, mini+1, 2000)
# ---> 85 loglike_values = np.array([-2*likely(liste_n, liste_nS, liste_nB, pS, pB, wS, wB, mu)])
#      87 plt.plot(mu_axis_values, loglike_values - min(loglike_values), label="log-likelihood")
#      88 plt.hlines(1, min(mu_axis_values), max(mu_axis_values), linestyle="--", color="tab:gray")
#
# NameError: name 'mu' is not defined

# %% [markdown]
# Correlation Matrix

# %%
# Data (PRI + DER)
pd.set_option("display.max_columns", None)
pd_dataset = ingestion.model.training_set["data"]

# Labels (1 signal, 0 background)
labels = ingestion.model.training_set["labels"]

# Splitting data into signal and background
data_signal = pd_dataset[labels == 1]
data_background = pd_dataset[labels == 0]
assert len(pd_dataset) == len(data_signal) + len(data_background)

# Correlation matrix
pd_dataset_njets = pd_dataset.drop("PRI_n_jets", axis="columns")
corr_mat = pd_dataset_njets.corr()
heatmap(corr_mat, annot=False, cbar=True, center=0.0)

# %%
# Feature selection based on correlation matrix

# Features to remove because they are highly correlated

def feature_corr_filtering(corr_mat, threshold, importance=False):
    # Create a dataframe with features with correlation above a given threshold
    corr_matrix = corr_mat.abs().unstack()
    corr_matrix = corr_matrix.sort_values(ascending=False)
    corr_matrix = corr_matrix[corr_matrix >= threshold]
    corr_matrix = corr_matrix[corr_matrix < 1]
    corr_matrix = corr_matrix.reset_index()
    corr_matrix.columns = ['feature1', 'feature2', 'Correlation']
    corr_matrix = corr_matrix.loc[0::2]
    corr_matrix.reset_index(drop=True)

    # Remove features based on feature score
    feat_to_rm = set()
    feat_to_keep = set()
    if importance:
        for i in range(len(corr_matrix)-1):
            if corr_matrix.iloc[i]["feature1"] in feat_to_keep:
                if corr_matrix.iloc[i]["feature2"] in feat_to_keep:
                    continue
                feat_to_rm.add(corr_matrix.iloc[i]["feature2"])

            elif corr_matrix.iloc[i]["feature2"] in features_to_keep:
                feat_to_rm.add(corr_matrix.iloc[i]["feature1"])

            elif feature_imp[corr_matrix.iloc[i]["feature1"]] > feature_imp[corr_matrix.iloc[i]["feature2"]]:
                feat_to_rm.add(corr_matrix.iloc[i]["feature2"])
                feat_to_keep.add(corr_matrix.iloc[i]["feature1"])

            else:
                feat_to_rm.add(corr_matrix.iloc[i]["feature1"])
                feat_to_keep.add(corr_matrix.iloc[i]["feature2"])

    else:
        for i in range(len(corr_matrix)-1):
            if corr_matrix.iloc[i]["feature1"] in feat_to_keep:
                if corr_matrix.iloc[i]["feature2"] in feat_to_keep:
                    continue
                feat_to_rm.add(corr_matrix.iloc[i]["feature2"])

            elif corr_matrix.iloc[i]["feature2"] in features_to_keep:
                feat_to_rm.add(corr_matrix.iloc[i]["feature1"])

            else:
                feat_to_rm.add(corr_matrix.iloc[i]["feature2"])
                feat_to_keep.add(corr_matrix.iloc[i]["feature1"])

    return feat_to_rm

feature_corr_filtering(corr_mat, 0.6)

# %% [markdown]
# Feature overlapping

# %%
feature_list=  ['DER_mass_vis', 'PRI_met', 'DER_mass_transverse_met_lep', 'DER_deltar_tau_lep', 'DER_met_phi_centrality', 'PRI_jet_all_pt', 'PRI_lep_pt', 'DER_pt_h', 'DER_pt_ratio_lep_tau', 'PRI_had_pt', 'DER_sum_pt', 'DER_mass_jet_jet', 'PRI_lep_eta', 'PRI_jet_subleading_pt', 'PRI_jet_leading_eta', 'DER_deltaeta_jet_jet', 'DER_prodeta_jet_jet', 'DER_lep_eta_centrality', 'DER_pt_tot', 'PRI_had_eta', 'PRI_jet_leading_pt', 'PRI_jet_subleading_phi', 'PRI_jet_subleading_eta', 'PRI_lep_phi', 'PRI_met_phi', 'PRI_jet_leading_phi','PRI_had_phi']
for i in range(len(feature_list)):
    background,_=np.histogram(data_background[feature_list[i]],100)
    signal,_=np.histogram(data_signal[feature_list[i]],100)

    plt.figure(figsize=(10, 6))
    _,bins,_=plt.hist(data_background[feature_list[i]],100, alpha=0.5, label='Background', density=True, color='blue', edgecolor='black')
    plt.hist(data_signal[feature_list[i]],bins, alpha=0.5, label='Signal', density=True, color='red', edgecolor='black')
    plt.title(feature_list[i])
    plt.legend()


    overlap=np.minimum(background, signal)
    print(np.sum(overlap), feature_list[i])

# %%
# load test set
data.load_test_set()
# Out:
# [*] Loading Test data
# [*] Test data loaded successfully

# %%
# predict submission
ingestion.predict_submission(test_settings)
# Out:
# [*] Calling predict method of submitted model
# Test Results:  {'mu_hat': -2.934557641492783, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2934557641492783, 'del_mu_tot': 0.1467333854752644}
# Test Results:  {'mu_hat': -2.941967136961343, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2941967136961343, 'del_mu_tot': 0.14710384638861293}
# Test Results:  {'mu_hat': -2.941967136961343, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2941967136961343, 'del_mu_tot': 0.14710384638861293}
# Test Results:  {'mu_hat': -2.941967136961343, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2941967136961343, 'del_mu_tot': 0.14710384638861293}
# Test Results:  {'mu_hat': -2.941967136961343, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2941967136961343, 'del_mu_tot': 0.14710384638861293}
# Test Results:  {'mu_hat': -2.934557641492783, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2934557641492783, 'del_mu_tot': 0.1467333854752644}
# Test Results:  {'mu_hat': -2.934557641492783, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2934557641492783, 'del_mu_tot': 0.1467333854752644}
# Test Results:  {'mu_hat': -2.941967136961343, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2941967136961343, 'del_mu_tot': 0.14710384638861293}
# Test Results:  {'mu_hat': -2.934557641492783, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2934557641492783, 'del_mu_tot': 0.1467333854752644}
# Test Results:  {'mu_hat': -2.941967136961343, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2941967136961343, 'del_mu_tot': 0.14710384638861293}
# Test Results:  {'mu_hat': -2.941967136961343, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2941967136961343, 'del_mu_tot': 0.14710384638861293}
# Test Results:  {'mu_hat': -2.941967136961343, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2941967136961343, 'del_mu_tot': 0.14710384638861293}
# Test Results:  {'mu_hat': -2.934557641492783, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2934557641492783, 'del_mu_tot': 0.1467333854752644}
# Test Results:  {'mu_hat': -2.934557641492783, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2934557641492783, 'del_mu_tot': 0.1467333854752644}
# Test Results:  {'mu_hat': -2.941967136961343, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2941967136961343, 'del_mu_tot': 0.14710384638861293}
# Test Results:  {'mu_hat': -2.934557641492783, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2934557641492783, 'del_mu_tot': 0.1467333854752644}
# Test Results:  {'mu_hat': -2.941967136961343, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2941967136961343, 'del_mu_tot': 0.14710384638861293}
# Test Results:  {'mu_hat': -2.934557641492783, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2934557641492783, 'del_mu_tot': 0.1467333854752644}
# Test Results:  {'mu_hat': -2.934557641492783, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2934557641492783, 'del_mu_tot': 0.1467333854752644}
# Test Results:  {'mu_hat': -2.934557641492783, 'del_mu_stat': 0.0025416804860736797, 'del_mu_sys': 0.2934557641492783, 'del_mu_tot': 0.1467333854752644}

# %%
ingestion.compute_result()
# Out:
# [*] Saving ingestion result

# %%
# save result
ingestion.save_result(output_dir)

# %% [markdown]
# ## Score
# 1. Compute Scores
# 2. Visualize Scores

# %%
from HiggsML.score import Scoring

# %%
# Initialize Score
score = Scoring()

# %%
print(output_dir)
score.load_ingestion_results(prediction_dir = output_dir, score_dir = output_dir)
# Out:
# /home/chakkappai/Work/ST4_CS/Collaboration_D/sample_result_submission
# [*] Reading predictions
# [✔]

# %%
# Compute Score
score.compute_scores(test_settings)
# Out:
# [*] Computing scores
# [*] mu_hats: {'mu_hats': [-2.934557641492783, -2.934557641492783, -2.934557641492783, -2.934557641492783, -2.934557641492783, -2.934557641492783, -2.934557641492783, -2.934557641492783, -2.934557641492783, -2.934557641492783], 'delta_mu_hats': [0.1467333854752644, 0.1467333854752644, 0.1467333854752644, 0.1467333854752644, 0.1467333854752644, 0.1467333854752644, 0.1467333854752644, 0.1467333854752644, 0.1467333854752644, 0.1467333854752644], 'p16': [-3.0812910269680476, -3.0812910269680476, -3.0812910269680476, -3.0812910269680476, -3.0812910269680476, -3.0812910269680476, -3.0812910269680476, -3.0812910269680476, -3.0812910269680476, -3.0812910269680476], 'p84': [-2.787824256017519, -2.787824256017519, -2.787824256017519, -2.787824256017519, -2.787824256017519, -2.787824256017519, -2.787824256017519, -2.787824256017519, -2.787824256017519, -2.787824256017519]}
# ------------------
# Set 0
# ------------------
# MAE (avg): 7.2674537718713434
# RMSE (avg): 14.212977036877394
# Interval: 0.29346677095052875
# Coverage: 0.0
# Quantiles Score: -2.6787139856852162
# [*] mu_hats: {'mu_hats': [-2.941967136961343, -2.941967136961343, -2.941967136961343, -2.941967136961343, -2.941967136961343, -2.941967136961343, -2.941967136961343, -2.941967136961343, -2.941967136961343, -2.941967136961343], 'delta_mu_hats': [0.14710384638861293, 0.14710384638861293, 0.14710384638861293, 0.14710384638861293, 0.14710384638861293, 0.14710384638861293, 0.14710384638861293, 0.14710384638861293, 0.14710384638861293, 0.14710384638861293], 'p16': [-3.089070983349956, -3.089070983349956, -3.089070983349956, -3.089070983349956, -3.089070983349956, -3.089070983349956, -3.089070983349956, -3.089070983349956, -3.089070983349956, -3.089070983349956], 'p84': [-2.79486329057273, -2.79486329057273, -2.79486329057273, -2.79486329057273, -2.79486329057273, -2.79486329057273, -2.79486329057273, -2.79486329057273, -2.79486329057273, -2.79486329057273]}
# ------------------
# Set 1
# ------------------
# MAE (avg): 11.26797922712242
# RMSE (avg): 33.0509363581345
# Interval: 0.2942076927772259
# Coverage: 0.0
# Quantiles Score: -2.681226972976305
#
#
# ==================
# Overall Score
# ==================
# [*] --- RMSE: 23.632
# [*] --- MAE: 9.268
# [*] --- Interval: 0.294
# [*] --- Coverage: 0.0
# [*] --- Quantiles score: -4.85
# [*] --- Ingestion duration: None
# [✔]

# %%
# Visualize scatter plot of ground truth mu and predicted mu
visualization.visualize_scatter(ingestion_result_dict=ingestion.results_dict, 
                  ground_truth_mus=test_settings["ground_truth_mus"])

# %% [markdown]
# ## Submissions

# %%
from zipfile import ZipFile, ZIP_DEFLATED
from contextlib import closing
# -------------------------------------
# Zip files
# -------------------------------------
def zipdir(archivename, basedir):
    '''Zip directory, from J.F. Sebastian http://stackoverflow.com/'''
    assert os.path.isdir(basedir)
    with closing(ZipFile(archivename, "w", ZIP_DEFLATED)) as z:
        for root, dirs, files in os.walk(basedir):
            # NOTE: ignore empty directories
            for fn in files:
                if fn[-4:] != '.zip' and fn != '.DS_Store':
                    absfn = os.path.join(root, fn)
                    zfn = absfn[len(basedir):]  # XXX: relative path
                    z.write(absfn, zfn)

# %% [markdown]
# ### **Prepare the submission**

# %%
import datetime
the_date = datetime.datetime.now().strftime("%y-%m-%d-%H-%M")
code_submission = 'BlackSwan-code_submission_' + the_date + '.zip'
zipdir(code_submission, submission_dir)
print("Submit : " + code_submission + " to the competition")
# Out:
# Submit : BlackSwan-code_submission_24-06-02-20-52.zip to the competition
